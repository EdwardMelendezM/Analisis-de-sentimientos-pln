# %%
import pandas as pd
import os



directorio = "data"
archivos = os.listdir(directorio)

listadf = []

for archivo in archivos:

    # Rutas de los archivos CSV
    ruta_archivo = os.path.join(directorio, archivo)

    # Cargar los archivos CSV en dataframes

    df = pd.read_csv(ruta_archivo)
    listadf.append(df)
    

# Unir los dataframes
df_unido = pd.concat(listadf, ignore_index=True)

# Guardar el dataframe unido en un nuevo archivo CSV
df_unido.to_csv('datasetUnido/dataset.csv', index=False, sep=',')

# %%
dataset = pd.read_csv("datasetUnido/dataset.csv")
dataset
# Out:
#                           tweetDate            twitterId           handle  \
# 0    Mon Jul 31 22:58:29 +0000 2023  1503629801667514368     veronica_d55
# 1    Wed Aug 02 02:44:10 +0000 2023             38360437           mabu80
# 2    Sat Jul 29 19:17:30 +0000 2023           2437384945       imayahuel_
# 3    Fri Aug 04 16:11:42 +0000 2023            123703013  octaviocancinoo
# 4    Thu Aug 03 00:18:35 +0000 2023            328190515    GDPerticarari
# ..                              ...                  ...              ...
# 968  Thu Jun 29 18:26:25 +0000 2023             79415826           totipm
# 969  Sun Dec 11 17:32:44 +0000 2022             72053500         serdna27
# 970  Wed Apr 19 02:20:16 +0000 2023             14235803       josepvives
# 971  Wed Mar 29 01:45:42 +0000 2023             41766743   Fidelsaavedrab
# 972  Thu Mar 09 03:32:00 +0000 2023  1549397139595399168           ch0fas
#
#                                                   text  \
# 0    lo q más me gusta de chatgpt es q no entiendo ...
# 1    @VeroRuizdelVizo Incluso, aunque yo uso el fre...
# 2    Lo que más me gusta de Chatgpt es que le doy o...
# 3    @CopyRebeldia Interesante, en lo personal me g...
# 4    Ah, ahora sí me gusta más ChatGPT. https://t.c...
# ..                                                 ...
# 968  @Conversation_E @evaladro @unicomplutense Tend...
# 969  ChatGPT, va a realizar en mi opinion la mayor ...
# 970  @Picanumeros @GedOmbra R sin estadistica! La i...
# 971  He estado probando #ChatGPT y en mi opinión es...
# 972  chatGPT está medio sobrevalorado en mi opinión...
#
#                               profileUrl  \
# 0       https://twitter.com/veronica_d55
# 1             https://twitter.com/mabu80
# 2         https://twitter.com/imayahuel_
# 3    https://twitter.com/octaviocancinoo
# 4      https://twitter.com/GDPerticarari
# ..                                   ...
# 968           https://twitter.com/totipm
# 969         https://twitter.com/serdna27
# 970       https://twitter.com/josepvives
# 971   https://twitter.com/Fidelsaavedrab
# 972           https://twitter.com/ch0fas
#
#                                                   name  \
# 0                                                vero𓆙
# 1                        María Alejandra Bello Uztáriz
# 2                             Stereotypical Mayahuel 🍶
# 3                                         tavo sanchez
# 4                           David (Gastón) Perticarari
# ..                                                 ...
# 968                                    Projecte Fressa
# 969                                             Serdna
# 970  JosepVives is on Mastodont #Data #Energy #Climate
# 971                                     ♬𝕴𝖗𝖔𝖓 𝕹𝖆𝖎𝖉𝖊𝖓 ♬
# 972                                             Sofi 🎸
#
#                                              tweetLink  \
# 0    https://twitter.com/veronica_d55/status/168614...
# 1    https://twitter.com/mabu80/status/168656854605...
# 2    https://twitter.com/imayahuel_/status/16853689...
# 3    https://twitter.com/octaviocancinoo/status/168...
# 4    https://twitter.com/GDPerticarari/status/16868...
# ..                                                 ...
# 968  https://twitter.com/totipm/status/167448448104...
# 969  https://twitter.com/serdna27/status/1601993400...
# 970  https://twitter.com/josepvives/status/16485118...
# 971  https://twitter.com/Fidelsaavedrab/status/1640...
# 972  https://twitter.com/ch0fas/status/163367195529...
#
#                     timestamp  \
# 0    2023-08-08T15:08:11.033Z
# 1    2023-08-08T15:08:11.033Z
# 2    2023-08-08T15:08:11.033Z
# 3    2023-08-08T15:08:11.033Z
# 4    2023-08-08T15:08:11.033Z
# ..                        ...
# 968  2023-08-08T03:57:22.627Z
# 969  2023-08-08T03:57:22.627Z
# 970  2023-08-08T03:57:22.627Z
# 971  2023-08-08T03:57:22.627Z
# 972  2023-08-08T03:57:22.627Z
#
#                                                  query
# 0    https://twitter.com/search?q=me%20gusta%20chat...
# 1    https://twitter.com/search?q=me%20gusta%20chat...
# 2    https://twitter.com/search?q=me%20gusta%20chat...
# 3    https://twitter.com/search?q=me%20gusta%20chat...
# 4    https://twitter.com/search?q=me%20gusta%20chat...
# ..                                                 ...
# 968  https://twitter.com/search?q=chatgpt%20en%20mi...
# 969  https://twitter.com/search?q=chatgpt%20en%20mi...
# 970  https://twitter.com/search?q=chatgpt%20en%20mi...
# 971  https://twitter.com/search?q=chatgpt%20en%20mi...
# 972  https://twitter.com/search?q=chatgpt%20en%20mi...
#
# [973 rows x 9 columns]
