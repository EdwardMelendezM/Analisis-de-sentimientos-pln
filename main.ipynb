# %%
import pandas as pd
import numpy as np
import os

# %%
directorio = "data"
archivos = os.listdir(directorio)
    
listadf = []

for archivo in archivos:

    # Rutas de los archivos CSV
    ruta_archivo = os.path.join(directorio, archivo)

    # Cargar los archivos CSV en dataframes

    df = pd.read_csv(ruta_archivo)
    listadf.append(df)
    

# Unir los dataframes
df_unido = pd.concat(listadf, ignore_index=True)

# Guardar el dataframe unido en un nuevo archivo CSV
df_unido.to_csv('datasetUnido/dataset.csv', index=False, sep=',')

# %%
dataset = pd.read_csv("datasetUnido/dataset.csv")
for valor in dataset["text"]:
    print(valor)
# Out:
# lo q más me gusta de chatgpt es q no entiendo algo y me lo explica re piola ojalá un día de estos también me explique xq él no m elige😔
# @VeroRuizdelVizo Incluso, aunque yo uso el free plan con el 3.5 siento lo mismo. Me gusta más como desarrolla las ideas ChatGPT que Bard.
# Lo que más me gusta de Chatgpt es que le doy ordenes y le pregunto directamente algo y no se ofende. Siento endorfinas, pana.
#
# Como colombianos nos estan crackeando el cerebro.
# @CopyRebeldia Interesante, en lo personal me gusta mucho Chatgpt pero sin duda iré a probar bard
# Ah, ahora sí me gusta más ChatGPT. https://t.co/AJmmrmUtMS
# @libercarpincho Lo que me gusta de chat gpt es pedirle que me recuerde la estructura de algun patrón de diseño en algún lenguaje especifico y lo hace
# ...
